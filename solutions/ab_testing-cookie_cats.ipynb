# %% [markdown]
# # Mobile phone game user retention analysis

# %% [markdown]
# ## 1 Introduction
#
# In the present notebook, we will use the chi squared and Fisher's exact test to analyse the dependence between user retention and a game version assignment.
#
# ## 2 Executive summary
#
# [SUMMARY HERE]
#
# ## 3 Report
#
# ### 3.1 Report introduction
#
# The dataset is a cross-section...
#
# The present dataset comes from DataCamp's [A/B Testing in R](https://app.datacamp.com/learn/courses/ab-testing-in-r?cf-exp=comm--ai-native-cdp-layout%3Aon) course.
#
# ### 3.2 Deliverables
#
# [DELIVERABLES HERE]
#
# ### 3.3 Methods
#
# [METHODS HERE]
#
# ### 3.4 Discussion
#
# [DISCUSSION HERE]
#
# ### 3.5 Recommendations
#
# [RECOMMENDATIONS HERE]

# %%
# Libraries
library(tidyverse)

# %% [markdown]
# ## Workings

# %% [markdown]
# ### Helpers

# %%
#

# %% [markdown]
# #### Graphing setup

# %%
# Set up Jupyter graph display
options(
  repr.plot.width = 10,
  repr.plot.height = 6,
  repr.plot.res = 150
)

# %% [markdown]
# ### Load and verify the data

# %%
#

# %% [markdown]
# #### Investigate NAs, negatives, duplicates

# %%
#

# %% [markdown]
# ### Difference between the groups
#
# - use the chi squared test to analyse the dependence between retention and gate assignment
# - use a random subsample of cardinality 1000 to analyse the dependence using Fisher's exact test

# %%
#
